# %% [markdown]
# <a href="https://colab.research.google.com/github/MB581/GenAI/blob/main/Califoria_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1.0 Call liraries
import pandas as pd
import numpy as np

#1.0.1
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
#1.1 Display multiple commands output from cell
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
df = pd.read_csv('/content/sample_data/california_housing_train.csv')

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
df.shape
print("\n=====\n")
df.dtypes
# Out:
# (17000, 9)
# =====
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# dtype: object

# %%
y = df.pop('median_house_value')
X = df

# %%
model = tf.keras.Sequential()

# %%
model.add(layers.Input(shape = (8,) ))

# %%
model.add(layers.Dense(32, activation = 'relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(32, activation = 'relu'))
model.add(layers.Dropout(0.5))

# %%
model.add(layers.Dense(1, activation = 'relu'))

# %%
model.compile(loss = 'mae')

# %%
model.fit(X,y, epochs = 500 )
# Out:
# Epoch 1/500
# 532/532 [==============================] - 2s 3ms/step - loss: 96032.3438
# Epoch 2/500
# 532/532 [==============================] - 1s 3ms/step - loss: 81186.1641
# Epoch 3/500
# 532/532 [==============================] - 1s 3ms/step - loss: 78848.3125
# Epoch 4/500
# 532/532 [==============================] - 1s 3ms/step - loss: 77815.3672
# Epoch 5/500
# 532/532 [==============================] - 2s 3ms/step - loss: 75983.7031
# Epoch 6/500
# 532/532 [==============================] - 2s 4ms/step - loss: 76231.7500
# Epoch 7/500
# 532/532 [==============================] - 2s 4ms/step - loss: 76604.6953
# Epoch 8/500
# 532/532 [==============================] - 2s 3ms/step - loss: 75471.9844
# Epoch 9/500
# 532/532 [==============================] - 2s 3ms/step - loss: 75064.2578
# Epoch 10/500
# 532/532 [==============================] - 1s 3ms/step - loss: 74466.4375
# Epoch 11/500
# 532/532 [==============================] - 1s 3ms/step - loss: 75013.8281
# ...

# %%
pred = model.predict(X)
pred
# Out:
# 532/532 [==============================] - 1s 2ms/step
# array([[29477.248],
#        [24029.248],
#        [31011.152],
#        ...,
#        [36464.816],
#        [26405.709],
#        [55511.64 ]], dtype=float32)
